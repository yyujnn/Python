# %% [markdown]
# ### if문

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
if True: 
    print('실행문장 실행')
# Out:
# 실행문장 실행

# %%
# if 문에서 조건문이 False일때 아무것도 실행되지 않는다.
if False:
    print('실행문장 실행')

# %% [markdown]
# #### 들여쓰기의 중요성

# %%
if True:
    print('실행문장 실행')
print('if문 밖에 있는 실행문장')
# Out:
# 실행문장 실행
# if문 밖에 있는 실행문장

# %%
# 들여쓰기를 무시했더니 False인데도 조건문 바깥의 문장이 실행되어버림
if False:
    print('실행문장 실행')
print('if문 밖에 있는 실행문장')
# Out:
# if문 밖에 있는 실행문장

# %%
money = 20000
if money >= 10000:
    print('택시를 타고 편하게 집에간다!!!^o^')
# Out:
# 택시를 타고 편하게 집에간다!!!^o^

# %% [markdown]
# ### if ~ else 문
# - 들여쓰기 주의~!!!

# %%
# 조건문 if ~ else를 활용해서 money가 만원 이상이면 택시, 만원 이하면 버스를 탄다는 출력문을 작성.
money = 8000
if money>= 10000:
    print('택시를 탄다')
else :
    print('버스를 탄다')
# Out:
# 버스를 탄다

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = int(input('정수 입력>> ' ))

if num%3==0 and num%5==0 :
    print(f'정수 {num}은(는) 3과 5의 배수입니다.')
else :
    print(f'정수 {num}은(는) 3과 5의 배수가 아닙니다.')
# Out:
# 정수 입력>> 7
# 정수 7은(는) 3과 5의 배수가 아닙니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cnt_mask = int(input('마스크 개수 입력 >> '))
wrap8 = cnt_mask//8

if cnt_mask-wrap8*8 == 0:
    wrap5 = 0
else :
    if cnt_mask-wrap8*8 > 0  and  cnt_mask-wrap8*8 <= 5 : 
        wrap5=1
    else :
        wrap5=2

        
# if cnt_mask >= 8 :
#     wrap8 = cnt_mask//8
#     wrap5 = cnt_mask%8//5
#     temp = cnt_mask%8%5
# else :
#     wrap5 = cnt_mask%8//5
#     temp = cnt_mask%8%5
    
# if temp>0 :
#     wrap5 +=1

    
print(f'8개들이 포장지 개수 : {wrap8} \n5개들이 포장지 개수 : {wrap5}')

print('8개들이 포장지 개수 : ', wrap8)
print('5개들이 포장지 개수 : ', wrap5)
# Out:
# 마스크 개수 입력 >> 23
# 8개들이 포장지 개수 : 2
# 5개들이 포장지 개수 : 2
# 8개들이 포장지 개수 2
# 5개들이 포장지 개수 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#if ~ elif 활용하여 두 수의 크기 비교하기

num1 = int(input('첫 번째 정수 입력 >> '))
num2 = int(input('두 번째 정수 입력 >> '))

if num1> num2 :
    print('첫 번째 정수가 더 큽니다.')
elif num1<num2 :
    print('두 번째 정수가 더 큽니다.')
else :
    print('두 수가 똑같습니다.')
# Out:
# 첫 번째 정수 입력 >> 8
# 두 번째 정수 입력 >> 8
# 두 수가 똑같습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
score = int(input('점수 입력 >> '))
grade =''

if score<=100 and score>=90 :
    grade = 'A'
elif score<90 and score >=80 :
    grade = 'B'
elif score<80 and score>=70 :
    grade = 'C'
elif score<70 and score>=60 :
    grade = 'D'
else :
    grade = 'F'
    
'{}점 은(는) {}학점 입니다.'.format(score,grade)
# Out:
# 점수 입력 >> 45
# '45점 은(는) F학점 입니다.'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("""
================================================
================---- 자판기 ----================
================================================
== 1.콜라 == 2.사이다 ==  3.물  =======insert===
==--------==----------==--------=======------===
==   600  ==    800   ==  1000  ======= 000원===
=======================================------===
================================================
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==+++++++++++++++              +++++++++++++++==
==+++++++++++++++     SMHRD    +++++++++++++++==
==+++++++++++++++              +++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
================================================
================================================
  ===                                      ===
  ===                                      ===""")
# Out:
# ...
# ================---- 자판기 ----================
# ...
# == 1.콜라 == 2.사이다 ==  3.물  =======insert===
# ==--------==----------==--------=======------===
# ==   600  ==    800   ==  1000  ======= 000원===
# =======================================------===
# ...
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==+++++++++++++++              +++++++++++++++==
# ==+++++++++++++++     SMHRD    +++++++++++++++==
# ==+++++++++++++++              +++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ...
#   ===                                      ===
#   ===                                      ===

# %%
money = int(input('금액 넣기 >> '))
menu = int(input('메뉴 선택(번호 입력) >> '))

if menu ==1:
    change = money-600
elif menu ==2:
    change= money-800
elif menu ==3:
    change= money-1000

if change < 0 :
    print('금액이 부족')
else :
    cheon = change//1000
    obaek = change%1000//500
    baek = change%1000%500//100
    print(f'1000원 {cheon}개, 500원 {obaek}개, 100원{baek}개')
# Out:
# 금액 넣기 >> 10000
# 메뉴 선택(번호 입력) >> 2
# 1000원 9개, 500원 0개, 100원2개
