# %% [markdown]
# ### 1. 키보드로 변수 num을 입력 받고 num이 3의 배수이면서 5의 배수이면<br>"3과 5의 배수입니다"를 출력하고 아니라면 "3과 5의 배수가 아닙니다"를 출력
# ![%EC%A1%B0%EA%B1%B4%EB%AC%B81.png](attachment:%EC%A1%B0%EA%B1%B4%EB%AC%B81.png)

# %%
# 코드 입력

# %% [markdown]
# ### 2. 변수 num1과 num2에 숫자를 입력 받아 크기를 비교
# ![%EC%A1%B0%EA%B1%B4%EB%AC%B82.png](attachment:%EC%A1%B0%EA%B1%B4%EB%AC%B82.png)

# %%
# 코드 입력

# %% [markdown]
# ### 3. 인덱싱, 슬라이싱, 조건문 예제
# 1. 이름과 주민번호 앞에서부터 7자리를 입력 받은 후 인덱싱과 슬라이싱을 활용하여<br>년, 월, 일, 성별을 각각의 변수에 저장
# ![%EC%A1%B0%EA%B1%B4%EB%AC%B83-1.png](attachment:%EC%A1%B0%EA%B1%B4%EB%AC%B83-1.png)

# %% [markdown]
# 2. 성별을 판별하는 조건문을 만들고 다음과 같이 출력
# ![%EC%A1%B0%EA%B1%B4%EB%AC%B83-2.png](attachment:%EC%A1%B0%EA%B1%B4%EB%AC%B83-2.png)

# %%
# 코드 입력

# %% [markdown]
# ### 변수 score에 점수를 입력 받아서 다음과 같이 학점을 부여
# ![%EC%A1%B0%EA%B1%B4%EB%AC%B84.png](attachment:%EC%A1%B0%EA%B1%B4%EB%AC%B84.png)

# %%
# 코드 입력
