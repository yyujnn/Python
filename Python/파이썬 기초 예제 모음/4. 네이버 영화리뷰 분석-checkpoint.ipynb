# %% [markdown]
# # pickle 라이브러리를 활용한 for문 예제

# %% [markdown]
# ### pickle 라이브러리란?
# - 텍스트 상태의 데이터가 아닌 리스트 혹은 클래스와 같은 자료형 객체를 저장하거나 불러오는 방법
# ![%ED%94%BC%ED%81%B41.png](attachment:%ED%94%BC%ED%81%B41.png)

# %% [markdown]
# ## 잠깐! 데이터 로드 하기 전 확인
# - 파일 다운로드 유무 (movie_review.pkl)
# - 파일 경로 (현재 디렉토리와 같은 위치에 저장할 것)

# %% [markdown]
# ### pickle 라이브러리를 활용하여 데이터 로드
# ![%ED%94%BC%ED%81%B42.png](attachment:%ED%94%BC%ED%81%B42.png)

# %%
# 코드 작성
import pickle

# <pickle 파일 오픈 모드>
# 'wb' : write binary 모드(읽고 쓰기 가능)
# 'rb' : read binary 모드

# binary : 컴퓨터가 처리하는 파일 형식(사람이 읽기 힘듦)

with open('movie_review.pkl', 'rb') as f :
    my = pickle.load(f)

# %% [markdown]
# #### Step!
# 1. 전체 데이터의 개수 확인
# 2. 리뷰만 출력
# 3. 리뷰 길이 최댓값 / 리뷰의 내용
# 4. 리뷰 길이 최솟값 / 리뷰의 내용
# 5. 리뷰 길이 평균값
# 6. 긍정리뷰 / 부정리뷰 개수
# 7. 특정 문자가 포함된 리뷰의 개수

# %% [markdown]
# ### 1. 전체 데이터 개수 확인
# ![%ED%94%BC%ED%81%B43.png](attachment:%ED%94%BC%ED%81%B43.png)

# %%
# 코드 입력

# %% [markdown]
# ### 2. 리뷰만 출력
# ![%ED%94%BC%ED%81%B44.png](attachment:%ED%94%BC%ED%81%B44.png)

# %%
# 코드 입력

# %% [markdown]
# ### 3. 리뷰 길이 최댓값 / 리뷰의 내용
# ![%ED%94%BC%ED%81%B45.png](attachment:%ED%94%BC%ED%81%B45.png)

# %%
# 코드 입력

# %% [markdown]
# ### 4. 리뷰 길이 최솟값 / 리뷰의 내용
# ![%ED%94%BC%ED%81%B46.png](attachment:%ED%94%BC%ED%81%B46.png)

# %%
# 코드 입력

# %% [markdown]
# ### 5. 리뷰 길이 평균값
# ![%ED%94%BC%ED%81%B47.png](attachment:%ED%94%BC%ED%81%B47.png)

# %%
# 코드 입력

# %% [markdown]
# ### 6. 긍정리뷰 / 부정리뷰 개수
# - 1은 긍정 / 0은 부정
# ![%ED%94%BC%ED%81%B48.png](attachment:%ED%94%BC%ED%81%B48.png)

# %%
# 코드 입력
# 1은 긍정 / 0은 부정

# %% [markdown]
# ### 7. 특정 문자가 포함된 리뷰 개수
# ![%ED%94%BC%ED%81%B49.png](attachment:%ED%94%BC%ED%81%B49.png)

# %%
# 코드 입력
